# %% [markdown]
# <a href="https://colab.research.google.com/github/EmmanueleVilla/quantum_computing/blob/main/Colab_09_Porte_quantistiche.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit --quiet && pip install pylatexenc --quiet

# %%
import numpy as np
import qiskit as qk
from qiskit.visualization import plot_histogram, array_to_latex
from qiskit.tools.visualization import plot_bloch_multivector, plot_bloch_vector, plot_state_qsphere
import matplotlib.pyplot as plt
import matplotlib.ticker as tck

from qiskit.quantum_info import SparsePauliOp, Statevector

import math

# %matplotlib inline

# %%
state_vector_simulator = qk.Aer.get_backend("statevector_simulator")
quantum_simulator = qk.Aer.get_backend("qasm_simulator")

# %%
def get_state(circuit):
  job = qk.execute(circuit, backend=state_vector_simulator)
  result = job.result()
  return result.get_statevector()

# %%
def get_counts(circuit):
  job = qk.execute(circuit, backend=quantum_simulator)
  result = job.result()
  return result.get_counts()

# %% [markdown]
# ## Porta U

# %%
circuit = qk.QuantumCircuit(1)
circuit.u(np.pi/4, 0, 0, 0)
circuit.draw(output="mpl")

# %%
array_to_latex(get_state(circuit))
# Out:
# $$
#
# \begin{bmatrix}
# 0.9238795325 & 0.3826834324  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(get_state(circuit))

# %%
circuit = qk.QuantumCircuit(1)
circuit.u(np.pi/4, np.pi/2, 0, 0)
circuit.draw(output="mpl")

# %%
array_to_latex(get_state(circuit))
# Out:
# $$
#
# \begin{bmatrix}
# 0.9238795325 & 0.3826834324 i  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(get_state(circuit))

# %%
circuit = qk.QuantumCircuit(1)
circuit.u(np.pi/4, np.pi/2, np.pi/6, 0)
circuit.draw(output="mpl")

# %%
array_to_latex(get_state(circuit))
# Out:
# $$
#
# \begin{bmatrix}
# 0.9238795325 & 0.3826834324 i  \\
#  \end{bmatrix}
# $$

# %%
plot_state_qsphere(get_state(circuit))

# %% [markdown]
# ## Porta identità

# %%
circuit = qk.QuantumCircuit(2)
circuit.h(0)
circuit.h(0)
circuit.barrier()
circuit.h(1)
circuit.draw(output="mpl")

# %%
circuit = qk.QuantumCircuit(2)
circuit.h(0)
circuit.h(0)
circuit.i(1)
circuit.i(1)
circuit.h(1)
circuit.draw(output="mpl")

# %% [markdown]
# ## Pauli X

# %%
circuit = qk.QuantumCircuit(1)
circuit.x(0)
circuit.draw(output="mpl")

# %%
plot_bloch_multivector(get_state(circuit))

# %%
array_to_latex(get_state(circuit))
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 1  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ## Pauli Z

# %%
circuit = qk.QuantumCircuit(1)
circuit.u(np.pi/4, np.pi/2, np.pi/6, 0)
circuit.z(0)
circuit.draw(output="mpl")

# %%
plot_bloch_multivector(get_state(circuit))

# %% [markdown]
# ## Porta Hadamard

# %%
circuit = qk.QuantumCircuit(1)
circuit.h(0)
circuit.draw(output="mpl")

# %%
plot_bloch_multivector(get_state(circuit))

# %% [markdown]
# ## Rotazione Y

# %%
circuit = qk.QuantumCircuit(1)
circuit.ry(np.pi/4, 0)
plot_bloch_multivector(get_state(circuit))

# %%
array_to_latex(get_state(circuit))
# Out:
# $$
#
# \begin{bmatrix}
# 0.9238795325 & 0.3826834324  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ## Rotazione X

# %%
circuit = qk.QuantumCircuit(1)
circuit.rx(np.pi/4, 0)
plot_bloch_multivector(get_state(circuit))

# %%
array_to_latex(get_state(circuit))
# Out:
# $$
#
# \begin{bmatrix}
# 0.9238795325 & - 0.3826834324 i  \\
#  \end{bmatrix}
# $$

# %%
plot_state_qsphere(get_state(circuit))

# %% [markdown]
# ## Rotazione Z

# %%
circuit = qk.QuantumCircuit(1)
circuit.rz(np.pi/4, 0)
plot_bloch_multivector(get_state(circuit))

# %%
array_to_latex(get_state(circuit))
# Out:
# $$
#
# \begin{bmatrix}
# 0.9238795325 - 0.3826834324 i & 0  \\
#  \end{bmatrix}
# $$

# %%
plot_state_qsphere(get_state(circuit))

# %%
circuit.measure_all()
plot_histogram(get_counts(circuit))
# Out:
# Result(backend_name='qasm_simulator', backend_version='0.12.2', qobj_id='', job_id='419d8784-20c7-4927-bc47-a6227e1a88e9', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 1024}), header=QobjExperimentHeader(creg_sizes=[['meas', 1]], global_phase=0.0, memory_slots=1, n_qubits=1, name='circuit-167', qreg_sizes=[['q', 1]], metadata={}), status=DONE, seed_simulator=2829199095, metadata={'noise': 'ideal', 'batched_shots_optimization': False, 'measure_sampling': True, 'parallel_shots': 1, 'remapped_qubits': False, 'active_input_qubits': [0], 'num_clbits': 1, 'parallel_state_update': 2, 'sample_measure_time': 0.00037103, 'num_qubits': 1, 'device': 'CPU', 'input_qubit_map': [[0, 0]], 'method': 'statevector', 'fusion': {'applied': False, 'max_fused_qubits': 5, 'threshold': 14, 'enabled': True}}, time_taken=0.00269503)], date=2023-07-20T10:11:59.925957, status=COMPLETED, header=None, metadata={'time_taken_execute': 0.0028
# ...

# %% [markdown]
# ## Rappresentazione dello stato di due qubit

# %%
circuit = qk.QuantumCircuit(2)
array_to_latex(get_state(circuit))
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ## Controlled CNOT

# %%
circuit = qk.QuantumCircuit(2)
circuit.cnot(0, 1)
circuit.draw(output="mpl")

# %%
plot_bloch_multivector(get_state(circuit))

# %%
circuit = qk.QuantumCircuit(2)
circuit.x(0)
circuit.cnot(0, 1)
circuit.draw(output="mpl")

# %%
plot_bloch_multivector(get_state(circuit))

# %%
circuit = qk.QuantumCircuit(2)
circuit.h(0)
circuit.cnot(0, 1)
circuit.draw(output="mpl")

# %%
plot_bloch_multivector(get_state(circuit))

# %%
plot_state_qsphere(get_state(circuit))

# %%
circuit = qk.QuantumCircuit(2)
circuit.ry(np.pi/4, 0)
circuit.cnot(0, 1)
circuit.draw(output="mpl")

# %%
plot_state_qsphere(get_state(circuit))

# %%
array_to_latex(get_state(circuit))
# Out:
# $$
#
# \begin{bmatrix}
# 0.9238795325 & 0 & 0 & 0.3826834324  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ## Circuit initialization

# %%
vector = [
    1 / math.sqrt(16) * complex(0, 1),
    1 / math.sqrt(8) * complex(1, 0),
    1 / math.sqrt(16) * complex(1, 1),
    0,
    0,
    1 / math.sqrt(8) * complex(1, 2),
    1 / math.sqrt(16) * complex(1, 0),
    0
]
vector
# Out:
# [0.25j,
#  (0.35355339059327373+0j),
#  (0.25+0.25j),
#  0,
#  0,
#  (0.35355339059327373+0.7071067811865475j),
#  (0.25+0j),
#  0]

# %%
q = qk.QuantumRegister(3)
q
# Out:
# QuantumRegister(3, 'q47')

# %%
circuit = qk.QuantumCircuit(q)
circuit

# %%
circuit.initialize(vector, [q[0], q[1], q[2]])

# %%
circuit.draw(output="mpl")

# %%
array_to_latex(get_state(circuit))
# Out:
# $$
#
# \begin{bmatrix}
# \frac{i}{4} & \frac{\sqrt{2}}{4} & \frac{1}{4} + \frac{i}{4} & 0 & 0 & \frac{\sqrt{2}}{4} + \frac{\sqrt{2} i}{2} & \frac{1}{4} & 0  \\
#  \end{bmatrix}
# $$
